# %%
# import library
import pandas as pd
import os
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load data from files of each month in 2019
frame=[]
length = []
for file in os.listdir("D:\Python project\Phân tích tình hình kinh doanh"):
    path = "D:\Python project\Phân tích tình hình kinh doanh/"
    pathfile = path + file
    df1 = pd.read_csv(pathfile)
    frame.append(df1)
    combine_data = pd.concat(frame)
    length_1month = len(df1.index)
    length.append(length_1month)
print(sum(length))
combine_data
# Out:
# 186850
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301
# ...               ...                                      ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
# Rename dataframe
df = combine_data

# %%
#Check data
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
# Get months
df["Month"] = df['Order Date'].str[:2]
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [186850 rows x 7 columns]

# %%
#check unique value in month for error
set(df['Month'])
# Out:
# {'01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '09',
#  '10',
#  '11',
#  '12',
#  'Or',
#  nan}

# %%
# Delete nan value
df= df.dropna()
df[df['Month']== 'Or']
df = df[df['Month']!= 'Or']
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [185950 rows x 7 columns]

# %% [markdown]
# # REPORTING

# %% [markdown]
# Q1: WHAT IS THE MONTHS HAVE THE BIGGEST AND LOWEST REVENUE? AND HOW MUCH?

# %%
# Check data type
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month               object
# dtype: object

# %%
# Change data type form object to numeric data type
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], downcast='integer')
df['Price Each'] = pd.to_numeric(df['Price Each'], downcast='float')
df.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered       int8
# Price Each          float32
# Order Date           object
# Purchase Address     object
# Month                object
# dtype: object

# %%
# Create Revenue column
df['Revenue'] = df['Price Each'] * df['Quantity Ordered']
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#            Order Date                         Purchase Address Month  \
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#           Revenue
# 0      700.000000
# 1       14.950000
# 2       23.980000
# 3      149.990005
# 4       11.990000
# ...           ...
# 11681    8.970000
# 11682  700.000000
# 11683  700.000000
# 11684  379.989990
# 11685   11.950000
#
# [185950 rows x 8 columns]

# %%
# Movingh revenue column
moving_column = df.pop('Revenue')
df.insert(4, 'Revenue', moving_column)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue      Order Date                         Purchase Address  \
# 0      700.000000  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       14.950000  01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       23.980000  01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3      149.990005  01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       11.990000  01/25/19 11:59            387 10th St, Austin, TX 73301
# ...           ...             ...                                      ...
# 11681    8.970000  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  700.000000  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  700.000000  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  379.989990  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685   11.950000  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#       Month
# 0        01
# 1        01
# 2        01
# 3        01
# 4        01
# ...     ...
# 11681    09
# 11682    09
# 11683    09
# 11684    09
# 11685    09
#
# [185950 rows x 8 columns]

# %%
# Caculate Revenue by month
df_Revenue_bymonth= df.groupby('Month').agg({
    'Revenue': 'sum'
})
df_Revenue_bymonth = df_Revenue_bymonth.sort_values('Revenue')
df_Revenue_bymonth
# Out:
#           Revenue
# Month
# 01     1822256.75
# 09     2097560.00
# 02     2202022.50
# 08     2244467.75
# 06     2577802.25
# 07     2647775.75
# 03     2807100.25
# 05     3152606.75
# 11     3199603.25
# 04     3390670.25
# 10     3736726.75
# 12     4613443.50

# %%
# What is moth that has the most and least 
revnueRevenue = df.groupby('Month').sum()['Revenue']
Month = range(1,13)
plt.bar(x=Month, height = Revenue, color = 'purple')
plt.xlabel('Months')
plt.ylabel('Revenue')
plt.xticks(Month)
plt.show()

# %% [markdown]
# Q2: WHAT IS CITY HAS THE MOST AND LEAST SALE?

# %%
#Check data frame
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue      Order Date                         Purchase Address  \
# 0      700.000000  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       14.950000  01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       23.980000  01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3      149.990005  01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       11.990000  01/25/19 11:59            387 10th St, Austin, TX 73301
# ...           ...             ...                                      ...
# 11681    8.970000  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  700.000000  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  700.000000  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  379.989990  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685   11.950000  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#       Month
# 0        01
# 1        01
# 2        01
# 3        01
# 4        01
# ...     ...
# 11681    09
# 11682    09
# 11683    09
# 11684    09
# 11685    09
#
# [185950 rows x 8 columns]

# %%
# Get city 
Address = lambda Address: Address.split(',')[1]
df['City'] =df['Purchase Address'].apply(Address)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue      Order Date                         Purchase Address  \
# 0      700.000000  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       14.950000  01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       23.980000  01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3      149.990005  01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       11.990000  01/25/19 11:59            387 10th St, Austin, TX 73301
# ...           ...             ...                                      ...
# 11681    8.970000  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  700.000000  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  700.000000  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  379.989990  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685   11.950000  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#       Month            City
# 0        01          Boston
# 1        01        Portland
# 2        01   San Francisco
# 3        01     Los Angeles
# 4        01          Austin
# ...     ...             ...
# 11681    09     Los Angeles
# 11682    09   San Francisco
# 11683    09   San Francisco
# 11684    09   San Francisco
# 11685    09   San Francisco
#
# [185950 rows x 9 columns]

# %%
# What is the city has the most and least revenue
df_Revenue_byCity = df.groupby('City').agg({
    'Revenue': 'sum'
}).sort_values('Revenue')
df_Revenue_byCity
# Out:
#                    Revenue
# City
#  Austin         1819581.75
#  Portland       2320490.50
#  Seattle        2747755.50
#  Dallas         2767975.50
#  Atlanta        2795498.50
#  Boston         3661642.00
#  New York City  4664317.50
#  Los Angeles    5452571.00
#  San Francisco  8262204.00

# %%
revenueByCity = df.groupby('City').sum()['Revenue'].sort_values()
City = [city for city, revenue in dff.items()]
fig, ax = plt.subplots(1 , 1 , figsize=(12,4))
plt.bar(x=City, height = revenueByCity, width=0.5, color = 'black')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Q3 WWEN COMPANY SHOW DISPLAY ADS TO MAXIMIZE THE LIKELIHOOD OFF PURCHASE?

# %%
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue      Order Date                         Purchase Address  \
# 0      700.000000  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       14.950000  01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       23.980000  01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3      149.990005  01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       11.990000  01/25/19 11:59            387 10th St, Austin, TX 73301
# ...           ...             ...                                      ...
# 11681    8.970000  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  700.000000  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  700.000000  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  379.989990  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685   11.950000  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#       Month            City
# 0        01          Boston
# 1        01        Portland
# 2        01   San Francisco
# 3        01     Los Angeles
# 4        01          Austin
# ...     ...             ...
# 11681    09     Los Angeles
# 11682    09   San Francisco
# 11683    09   San Francisco
# 11684    09   San Francisco
# 11685    09   San Francisco
#
# [185950 rows x 9 columns]

# %%
# Change data type from object to datiem
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Hour'] = df['Order Date'].dt.hour
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue          Order Date  \
# 0      700.000000 2019-01-22 21:25:00
# 1       14.950000 2019-01-28 14:15:00
# 2       23.980000 2019-01-17 13:33:00
# 3      149.990005 2019-01-05 20:33:00
# 4       11.990000 2019-01-25 11:59:00
# ...           ...                 ...
# 11681    8.970000 2019-09-17 20:56:00
# 11682  700.000000 2019-09-01 16:00:00
# 11683  700.000000 2019-09-23 07:39:00
# 11684  379.989990 2019-09-19 17:30:00
# 11685   11.950000 2019-09-30 00:18:00
#
#                               Purchase Address Month            City  Hour
# 0              944 Walnut St, Boston, MA 02215    01          Boston    21
# 1             185 Maple St, Portland, OR 97035    01        Portland    14
# 2        538 Adams St, San Francisco, CA 94016    01   San Francisco    13
# 3           738 10th St, Los Angeles, CA 90001    01     Los Angeles    20
# 4                387 10th St, Austin, TX 73301    01          Austin    11
# ...                                        ...   ...             ...   ...
# 11681   840 Highland St, Los Angeles, CA 90001    09     Los Angeles    20
# 11682  216 Dogwood St, San Francisco, CA 94016    09   San Francisco    16
# 11683     220 12th St, San Francisco, CA 94016    09   San Francisco     7
# 11684   511 Forest St, San Francisco, CA 94016    09   San Francisco    17
# 11685   250 Meadow St, San Francisco, CA 94016    09   San Francisco     0
#
# [185950 rows x 10 columns]

# %%
add_h = lambda h: (str(h) + "h")

# %%
df['Hour'] = df['Hour'].apply(add_h)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue          Order Date  \
# 0      700.000000 2019-01-22 21:25:00
# 1       14.950000 2019-01-28 14:15:00
# 2       23.980000 2019-01-17 13:33:00
# 3      149.990005 2019-01-05 20:33:00
# 4       11.990000 2019-01-25 11:59:00
# ...           ...                 ...
# 11681    8.970000 2019-09-17 20:56:00
# 11682  700.000000 2019-09-01 16:00:00
# 11683  700.000000 2019-09-23 07:39:00
# 11684  379.989990 2019-09-19 17:30:00
# 11685   11.950000 2019-09-30 00:18:00
#
#                               Purchase Address Month            City Hour
# 0              944 Walnut St, Boston, MA 02215    01          Boston  21h
# 1             185 Maple St, Portland, OR 97035    01        Portland  14h
# 2        538 Adams St, San Francisco, CA 94016    01   San Francisco  13h
# 3           738 10th St, Los Angeles, CA 90001    01     Los Angeles  20h
# 4                387 10th St, Austin, TX 73301    01          Austin  11h
# ...                                        ...   ...             ...  ...
# 11681   840 Highland St, Los Angeles, CA 90001    09     Los Angeles  20h
# 11682  216 Dogwood St, San Francisco, CA 94016    09   San Francisco  16h
# 11683     220 12th St, San Francisco, CA 94016    09   San Francisco   7h
# 11684   511 Forest St, San Francisco, CA 94016    09   San Francisco  17h
# 11685   250 Meadow St, San Francisco, CA 94016    09   San Francisco   0h
#
# [185950 rows x 10 columns]

# %%
RevenueByHour = df.groupby('Hour').count()['Revenue']
Hour= [hour for hour, revenue in RevenueByHour.items()]
fig, ax = plt.subplots(1 , 1 , figsize=(10,4))
plt.bar(x=Hour, height = RevenueByHour, width=0.3)
plt.xticks(Hour)
plt.show()

# %% [markdown]
# Q4 WHAT ARE PROFUCTS MOST OFTEN SOLD TOGETHER?

# %%
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue          Order Date  \
# 0      700.000000 2019-01-22 21:25:00
# 1       14.950000 2019-01-28 14:15:00
# 2       23.980000 2019-01-17 13:33:00
# 3      149.990005 2019-01-05 20:33:00
# 4       11.990000 2019-01-25 11:59:00
# ...           ...                 ...
# 11681    8.970000 2019-09-17 20:56:00
# 11682  700.000000 2019-09-01 16:00:00
# 11683  700.000000 2019-09-23 07:39:00
# 11684  379.989990 2019-09-19 17:30:00
# 11685   11.950000 2019-09-30 00:18:00
#
#                               Purchase Address Month            City Hour
# 0              944 Walnut St, Boston, MA 02215    01          Boston  21h
# 1             185 Maple St, Portland, OR 97035    01        Portland  14h
# 2        538 Adams St, San Francisco, CA 94016    01   San Francisco  13h
# 3           738 10th St, Los Angeles, CA 90001    01     Los Angeles  20h
# 4                387 10th St, Austin, TX 73301    01          Austin  11h
# ...                                        ...   ...             ...  ...
# 11681   840 Highland St, Los Angeles, CA 90001    09     Los Angeles  20h
# 11682  216 Dogwood St, San Francisco, CA 94016    09   San Francisco  16h
# 11683     220 12th St, San Francisco, CA 94016    09   San Francisco   7h
# 11684   511 Forest St, San Francisco, CA 94016    09   San Francisco  17h
# 11685   250 Meadow St, San Francisco, CA 94016    09   San Francisco   0h
#
# [185950 rows x 10 columns]

# %%
# Keep all duplicated Order ID
df_dup = df[df['Order ID'].duplicated(keep = False)]

# %%
# join products has the same Order ID
Product = lambda product: ', '.join(product)
df_dup.groupby('Order ID')['Product'].transform(joinProduct)
# Out:
# 41                USB-C Charging Cable, Wired Headphones
# 42                USB-C Charging Cable, Wired Headphones
# 57       Apple Airpods Headphones, AA Batteries (4-pack)
# 58       Apple Airpods Headphones, AA Batteries (4-pack)
# 133                    Vareebadd Phone, Wired Headphones
#                               ...
# 11628      34in Ultrawide Monitor, AA Batteries (4-pack)
# 11639           Wired Headphones, AAA Batteries (4-pack)
# 11640           Wired Headphones, AAA Batteries (4-pack)
# 11677                 Google Phone, USB-C Charging Cable
# 11678                 Google Phone, USB-C Charging Cable
# Name: Product, Length: 14649, dtype: object

# %%
df_dup['All Product'] = df_dup.groupby('Order ID')['Product'].transform(joinProduct)
df_dup
# Out:
# C:\Users\Tuananh\AppData\Local\Temp\ipykernel_1900\1373490961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dup['All Product'] = df_dup.groupby('Order ID')['Product'].transform(joinProduct)
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 41      141275      USB-C Charging Cable                 1       11.95
# 42      141275          Wired Headphones                 1       11.99
# 57      141290  Apple Airpods Headphones                 1      150.00
# 58      141290     AA Batteries (4-pack)                 3        3.84
# 133     141365           Vareebadd Phone                 1      400.00
# ...        ...                       ...               ...         ...
# 11628   259303     AA Batteries (4-pack)                 1        3.84
# 11639   259314          Wired Headphones                 1       11.99
# 11640   259314    AAA Batteries (4-pack)                 2        2.99
# 11677   259350              Google Phone                 1      600.00
# 11678   259350      USB-C Charging Cable                 1       11.95
#
#        Revenue          Order Date                        Purchase Address  \
# 41       11.95 2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301
# 42       11.99 2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301
# 57      150.00 2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001
# 58       11.52 2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001
# 133     400.00 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001
# ...        ...                 ...                                     ...
# 11628     3.84 2019-09-20 20:18:00           106 7th St, Atlanta, GA 30301
# 11639    11.99 2019-09-16 00:25:00      241 Highland St, Atlanta, GA 30301
# 11640     5.98 2019-09-16 00:25:00      241 Highland St, Atlanta, GA 30301
# 11677   600.00 2019-09-30 13:49:00   519 Maple St, San Francisco, CA 94016
# 11678    11.95 2019-09-30 13:49:00   519 Maple St, San Francisco, CA 94016
#
#       Month            City Hour  \
# 41       01          Austin  16h
# 42       01          Austin  16h
# 57       01     Los Angeles   8h
# 58       01     Los Angeles   8h
# 133      01   New York City  11h
# ...     ...             ...  ...
# 11628    09         Atlanta  20h
# 11639    09         Atlanta   0h
# 11640    09         Atlanta   0h
# 11677    09   San Francisco  13h
# 11678    09   San Francisco  13h
#
#                                            All Product
# 41              USB-C Charging Cable, Wired Headphones
# 42              USB-C Charging Cable, Wired Headphones
# 57     Apple Airpods Headphones, AA Batteries (4-pack)
# 58     Apple Airpods Headphones, AA Batteries (4-pack)
# 133                  Vareebadd Phone, Wired Headphones
# ...                                                ...
# 11628    34in Ultrawide Monitor, AA Batteries (4-pack)
# 11639         Wired Headphones, AAA Batteries (4-pack)
# 11640         Wired Headphones, AAA Batteries (4-pack)
# 11677               Google Phone, USB-C Charging Cable
# 11678               Google Phone, USB-C Charging Cable
#
# [14649 rows x 11 columns]

# %%
# drop duplicated row
df_dup = df_dup[['Order ID', 'All Product']].drop_duplicates()

# %%
# Most packed items
df_dup['All Product'].value_counts()
# Out:
# iPhone, Lightning Charging Cable                        882
# Google Phone, USB-C Charging Cable                      856
# iPhone, Wired Headphones                                361
# Vareebadd Phone, USB-C Charging Cable                   312
# Google Phone, Wired Headphones                          303
#                                                        ...
# Vareebadd Phone, Wired Headphones, iPhone                 1
# Google Phone, Wired Headphones, USB-C Charging Cable      1
# LG Washing Machine, Wired Headphones                      1
# LG Washing Machine, Google Phone                          1
# LG Washing Machine, AA Batteries (4-pack)                 1
# Name: All Product, Length: 366, dtype: int64

# %%
# Most pair items
from itertools import combinations
from collections import Counter

count = Counter()

for products in df_dup['All Product']:
    product_list = products.split(",")
    count.update(Counter(combinations(product_list, 2)))

for key, value in count.most_common(15):
    print(key, value)
# Out:
# ('iPhone', ' Lightning Charging Cable') 1005
# ('Google Phone', ' USB-C Charging Cable') 987
# ('iPhone', ' Wired Headphones') 447
# ('Google Phone', ' Wired Headphones') 414
# ('Vareebadd Phone', ' USB-C Charging Cable') 361
# ('iPhone', ' Apple Airpods Headphones') 360
# ('Google Phone', ' Bose SoundSport Headphones') 220
# ('Vareebadd Phone', ' Wired Headphones') 143
# (' USB-C Charging Cable', ' Wired Headphones') 120
# ('Vareebadd Phone', ' Bose SoundSport Headphones') 80
# (' Lightning Charging Cable', ' Wired Headphones') 62
# ('Lightning Charging Cable', ' USB-C Charging Cable') 55
# ('Lightning Charging Cable', ' AA Batteries (4-pack)') 52
# ('AA Batteries (4-pack)', ' Lightning Charging Cable') 51
# ('Lightning Charging Cable', ' Lightning Charging Cable') 51

# %% [markdown]
# Q5 WHAT IS THE PRODUCT SOLD THE MOST? AND WHY?

# %%
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#           Revenue          Order Date  \
# 0      700.000000 2019-01-22 21:25:00
# 1       14.950000 2019-01-28 14:15:00
# 2       23.980000 2019-01-17 13:33:00
# 3      149.990005 2019-01-05 20:33:00
# 4       11.990000 2019-01-25 11:59:00
# ...           ...                 ...
# 11681    8.970000 2019-09-17 20:56:00
# 11682  700.000000 2019-09-01 16:00:00
# 11683  700.000000 2019-09-23 07:39:00
# 11684  379.989990 2019-09-19 17:30:00
# 11685   11.950000 2019-09-30 00:18:00
#
#                               Purchase Address Month            City   Time  \
# 0              944 Walnut St, Boston, MA 02215    01          Boston  21:25
# 1             185 Maple St, Portland, OR 97035    01        Portland  14:15
# 2        538 Adams St, San Francisco, CA 94016    01   San Francisco  13:33
# 3           738 10th St, Los Angeles, CA 90001    01     Los Angeles  20:33
# 4                387 10th St, Austin, TX 73301    01          Austin  11:59
# ...                                        ...   ...             ...    ...
# 11681   840 Highland St, Los Angeles, CA 90001    09     Los Angeles  20:56
# 11682  216 Dogwood St, San Francisco, CA 94016    09   San Francisco  16:00
# 11683     220 12th St, San Francisco, CA 94016    09   San Francisco  07:39
# 11684   511 Forest St, San Francisco, CA 94016    09   San Francisco  17:30
# 11685   250 Meadow St, San Francisco, CA 94016    09   San Francisco  00:18
#
#       Hour
# 0      21h
# 1      14h
# 2      13h
# 3      20h
# 4      11h
# ...    ...
# 11681  20h
# 11682  16h
# 11683   7h
# 11684  17h
# 11685   0h
#
# [185950 rows x 11 columns]

# %%
# Total items sale by each product
mostProductSold = df.groupby('Product').sum()['Quantity Ordered']

# %%
df.groupby('Product').sum()['Revenue']
# Out:
# Product
# 20in Monitor                  4.541487e+05
# 27in 4K Gaming Monitor        2.435098e+06
# 27in FHD Monitor              1.132424e+06
# 34in Ultrawide Monitor        2.355558e+06
# AA Batteries (4-pack)         1.061184e+05
# AAA Batteries (4-pack)        9.274083e+04
# Apple Airpods Headphones      2.349150e+06
# Bose SoundSport Headphones    1.345565e+06
# Flatscreen TV                 1.445700e+06
# Google Phone                  3.319200e+06
# LG Dryer                      3.876000e+05
# LG Washing Machine            3.996000e+05
# Lightning Charging Cable      3.470942e+05
# Macbook Pro Laptop            8.037600e+06
# ThinkPad Laptop               4.129959e+06
# USB-C Charging Cable          2.865012e+05
# Vareebadd Phone               8.272000e+05
# Wired Headphones              2.464784e+05
# iPhone                        4.794300e+06
# Name: Revenue, dtype: float32

# %%
# Mean price of each product
meanPrice = df.groupby('Product').mean()['Price Each']

# %%
x = Product
y1 = mostProductSold
y2 = meanPrice

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(x, y1, color = 'red')
ax2.plot(x, y2, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')
ax2.set_ylabel('Y2 data', color='b')
ax1.set_xticklabels(Product, rotation=90, ha='right')


plt.show()
# Out:
# C:\Users\Tuananh\AppData\Local\Temp\ipykernel_1900\2615706041.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Product, rotation=90, ha='right')

# %%
#Check correlation peason
df.corr()
# Out:
#                   Quantity Ordered  Price Each   Revenue
# Quantity Ordered          1.000000   -0.148272 -0.139417
# Price Each               -0.148272    1.000000  0.999203
# Revenue                  -0.139417    0.999203  1.000000

# %%
plt.scatter(x=df['Revenue'], y=df['Price Each'])
plt.title('REVENUE AND PRICE')
plt.xlabel('REVENUE')
plt.ylabel('PRICE')
plt.show()

# %%
sns.regplot(x='Revenue', y='Price Each', data=df, scatter_kws = {"color": "black"}, line_kws = {"color":"purple"})
# Out:
# <AxesSubplot:xlabel='Revenue', ylabel='Price Each'>

# %%
df.groupby('Product').sum()['Quantity Ordered']
# Out:
# Product
# 20in Monitor                   4129.0
# 27in 4K Gaming Monitor         6244.0
# 27in FHD Monitor               7550.0
# 34in Ultrawide Monitor         6199.0
# AA Batteries (4-pack)         27635.0
# AAA Batteries (4-pack)        31017.0
# Apple Airpods Headphones      15661.0
# Bose SoundSport Headphones    13457.0
# Flatscreen TV                  4819.0
# Google Phone                   5532.0
# LG Dryer                        646.0
# LG Washing Machine              666.0
# Lightning Charging Cable      23217.0
# Macbook Pro Laptop             4728.0
# ThinkPad Laptop                4130.0
# USB-C Charging Cable          23975.0
# Vareebadd Phone                2068.0
# Wired Headphones              20557.0
# iPhone                         6849.0
# Name: Quantity Ordered, dtype: float64

# %%
df.groupby('Product').mean()['Price Each'].sort_values()
# Out:
# Product
# AAA Batteries (4-pack)           2.990000
# AA Batteries (4-pack)            3.840000
# USB-C Charging Cable            11.950000
# Wired Headphones                11.990000
# Lightning Charging Cable        14.950000
# Bose SoundSport Headphones      99.989998
# 20in Monitor                   109.989998
# 27in FHD Monitor               149.990005
# Apple Airpods Headphones       150.000000
# Flatscreen TV                  300.000000
# 34in Ultrawide Monitor         379.989990
# 27in 4K Gaming Monitor         389.989990
# Vareebadd Phone                400.000000
# Google Phone                   600.000000
# LG Washing Machine             600.000000
# LG Dryer                       600.000000
# iPhone                         700.000000
# ThinkPad Laptop                999.989990
# Macbook Pro Laptop            1700.000000
# Name: Price Each, dtype: float32
